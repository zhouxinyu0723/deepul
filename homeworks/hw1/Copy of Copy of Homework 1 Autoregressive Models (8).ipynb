# %%
# %%bash
# if [ ! -d deepul ]; then
#   git clone https://github.com/rll/deepul.git
#   unzip -qq deepul/homeworks/hw1/data/hw1_data.zip -d deepul/homeworks/hw1/data/
#   pip install ./deepul
# fi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./deepul
# Building wheels for collected packages: deepul
#   Building wheel for deepul (setup.py): started
#   Building wheel for deepul (setup.py): finished with status 'done'
#   Created wheel for deepul: filename=deepul-0.1.0-py3-none-any.whl size=16663 sha256=1a5401659f76b72b44f707dad5052917fbcbe4d054827ecf00534fe23d34c06d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mzhlr_gr/wheels/40/86/14/ae5eebf191515af53ab86be6749af0ae2a71269b38f187557d
# Successfully built deepul
# Installing collected packages: deepul
# Successfully installed deepul-0.1.0
# Cloning into 'deepul'...
# Checking out files: 100% (129/129), done.
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.

# %%
from deepul.hw1_helper import *

# %% [markdown]
# # Getting Started
#
# ## Overview
# This semester, all homeworks will be conducted through Google Colab notebooks. All code for the homework assignment will be written and run in this notebook. Running in Colab will automatically provide a GPU, but you may also run this notebook locally by following [these instructions](https://research.google.com/colaboratory/local-runtimes.html) if you wish to use your own GPU.
#
# You will save images in the notebooks to use and fill out a given LaTeX template which will be submitted to Gradescope, along with your notebook code.
#
# ## Using Colab
# On the left-hand side, you can click the different icons to see a Table of Contents of the assignment, as well as local files accessible through the notebook.
#
# Make sure to go to **Runtime -> Change runtime type** and select **GPU** as the hardware accelerator. This allows you to use a GPU. Run the cells below to get started on the assignment. Note that a session is open for a maximum of 12 hours, and using too much GPU compute may result in restricted access for a short period of time. Please start the homework early so you have ample time to work.
#
# **If you loaded this notebook from clicking "Open in Colab" from github, you will need to save it to your own Google Drive to keep your work.**
#
# ## General Tips
# In each homework problem, you will implement an autoregressive model and run it on two datasets (dataset 1 and dataset 2). The expected outputs for dataset 1 are already provided to help as a sanity check.
#
# Feel free to print whatever output (e.g. debugging code, training code, etc) you want, as the graded submission will be the submitted pdf with images.
#
# After you complete the assignment, download all of the image outputted in the results/ folder and upload them to the figure folder in the given latex template.
#
# Run the cells below to download and load up the starter code.

# %% [markdown]
# # Question 1: 1D Data
#
# In this question, we will train simple generative models on discrete 1D data.
#
# Execute the cell below to visualize our datasets

# %%
visualize_q1_data(dset_type=1)
visualize_q1_data(dset_type=2)
# Out:
# Dataset 1
# Dataset 2

# %% [markdown]
# ## Part (a) Fitting a Histogram
#
# Let $\theta = (\theta_0, \dots, \theta_{d-1}) \in \mathbb{R}^d$ and define the model $p_\theta(x) = \frac{e^{\theta_x}}{\sum_{x'}e^{\theta_{x'}}}$
#
# Fit $p_\theta$ with maximum likelihood via stochastic gradient descent on the training set, using $\theta$ initialized to zero. Use your favorite version of stochastic gradient descent, and optimize your hyperparameters on a validation set of your choice.
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. Plot the model probabilities in a bar graph with $\{0,\dots,d-1\}$ on the x-axis and a real number in $[0,1]$ on the y-axis.

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("GPU available, use GPU. :) ")
else:
  print("use CPU. :( ") 
class histo(nn.Module):
  def __init__(self, d):
    super(histo, self).__init__()
    self.d = d
    self.theta = torch.nn.parameter.Parameter(torch.zeros(self.d))

  def forward(self, x):
    likelyhood = self.p[x]
    loss = -torch.mean(torch.log(likelyhood))
    return loss
  @property
  def p(self):
    return torch.nn.functional.softmax(self.theta)
def q1_a(train_data, test_data, d, dset_id):
  """
  train_data: An (n_train,) numpy array of integers in {0, ..., d-1}
  test_data: An (n_test,) numpy array of integers in {0, .., d-1}
  d: The number of possible discrete values for random variable x
  dset_id: 
  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (d,) of model probabilities
  """
  # prepare data, model and optimizer 
  model = histo(d).to(device)
  optimizer = optim.Adadelta(model.parameters(), lr=0.1)
  # init output
  losses = []
  test_losses = [model(torch.from_numpy(test_data).to(device)).detach().numpy().item()]

  # traning model
  model.train()
  if dset_id == 1:
    iteration = 10000
  else:
    iteration = 20
  for iter in tqdm(range(iteration)):
    batch = np.random.choice(train_data,20)
    optimizer.zero_grad()
    loss = model(torch.from_numpy(batch).to(device))
    losses.append(loss.detach().numpy().item())
    test_losses.append(model(test_data).detach().numpy().item())
    loss.backward()
    optimizer.step()
    
  return losses, test_losses, model.p.detach().numpy()
    

  """ YOUR CODE HERE """
# Out:
# use CPU. :(

# %% [markdown]
# ### Results
#
# Once you've implemented `q1_a`, execute the cells below to visualize and save your results

# %%
q1_save_results(1, 'a', q1_a)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 100%|██████████| 10000/10000 [00:06<00:00, 1435.10it/s]
# Final Test Loss: 2.0608

# %%
q1_save_results(2, 'a', q1_a)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 100%|██████████| 20/20 [00:00<00:00, 570.33it/s]
# Final Test Loss: 4.6021

# %% [markdown]
# ## Part (b) Fitting Discretized Mixture of Logistics
#
# Let us model $p_\theta(x)$ as a **discretized** mixture of 4 logistics such that $p_\theta(x) = \sum_{i=1}^4 \pi_i[\sigma((x+0.5 - \mu_i)/s_i) - \sigma((x-0.5-\mu_i)/s_i)]$
#
# For the edge case of when $x = 0$, we replace $x-0.5$ by $-\infty$, and for $x = d-1$, we replace $x+0.5$ by $\infty$.
#
# You may find the [PixelCNN++](https://arxiv.org/abs/1701.05517) helpful for more information on discretized mixture of logistics.
#
# **Provide the same set of corresponding deliverables as part (a)**

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
class logistics(nn.Module):
  def __init__(self, d, param=4):
    super(logistics, self).__init__()
    self.d = d
    self.param = param
    self.high = torch.range(1,d)+0.5-int(d/2)
    self.high = self.high[None, :]
    self.low = torch.range(1,d)-0.5-int(d/2)
    self.low = self.low[None, :]
    self.shift = torch.nn.parameter.Parameter(100*torch.random.torch.torch.rand(self.param, 1))
    self.scale = torch.nn.parameter.Parameter(torch.random.torch.torch.rand(self.param, 1)-1)
    self.weight = torch.nn.parameter.Parameter(torch.random.torch.torch.rand(self.param, 1))

  def forward(self, x):
    likelyhood = self.p[x]
    loss = -torch.mean(torch.log(likelyhood))
    return loss
  @property
  def p(self):
    d_inidividual_p = torch.sigmoid((self.high-self.shift)*torch.nn.functional.softplus(self.scale)) - torch.sigmoid((self.low-self.shift)*torch.nn.functional.softplus(self.scale)) + 1e-10
    d_inidividual_p[:,0] = torch.sigmoid((self.high-self.shift)*torch.nn.functional.softplus(self.scale))[:,0] + 1e-10
    d_inidividual_p[:,-1] = 1-torch.sigmoid((self.low-self.shift)*torch.nn.functional.softplus(self.scale))[:,-1] + 1e-10
    p = torch.sum(torch.nn.functional.softmax(self.weight, dim=0)*d_inidividual_p, axis=0)
    return p


def q1_b(train_data, test_data, d, dset_id):
  """
  train_data: An (n_train,) numpy array of integers in {0, ..., d-1}
  test_data: An (n_test,) numpy array of integers in {0, .., d-1}
  d: The number of possible discrete values for random variable x
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (d,) of model probabilities
  """
  # prepare data, model and optimizer 
  model = logistics(d, 4).to(device)
  optimizer = optim.Adam(model.parameters(), lr=0.1)
  # init output
  losses = []
  test_losses = [model(torch.from_numpy(test_data).to(device)).detach().numpy().item()]

  # traning model
  model.train()
  if dset_id == 1:
    iteration = 10
  else:
    iteration = 1000
  for iter in tqdm(range(iteration)):
    batch = np.random.choice(train_data,128)
    optimizer.zero_grad()
    loss = model(torch.from_numpy(batch).to(device))
    losses.append(loss.detach().numpy().item())
    test_losses.append(model(test_data).detach().numpy().item())
    loss.backward()
    optimizer.step()
  return losses, test_losses, model.p.detach().numpy()
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q1_b`, execute the cells below to visualize and save your results

# %%
q1_save_results(1, 'b', q1_b)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#
# 100%|██████████| 10/10 [00:00<00:00, 255.45it/s]
# Final Test Loss: 6.2704

# %%
q1_save_results(2, 'b', q1_b)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#
# 100%|██████████| 1000/1000 [00:03<00:00, 252.43it/s]
# Final Test Loss: 4.0442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3fac48415013> in <module>
# ----> 1 q1_save_results(2, 'b', q1_b)
#
# /usr/local/lib/python3.7/dist-packages/deepul/hw1_helper.py in q1_save_results(dset_type, part, fn)
#      64     save_distribution_1d(train_data, distribution,
#      65                          f'Q1({part}) Dataset {dset_type} Learned Distribution',
# ---> 66                          f'results/q1_{part}_dset{dset_type}_learned_dist.png')
#      67
#      68
#
# /usr/local/lib/python3.7/dist-packages/deepul/utils.py in save_distribution_1d(data, distribution, title, fname)
#      54     plt.ylabel('Probability')
#      55     plt.legend()
# ---> 56     savefig(fname)
#      57
#      58
#
# /usr/local/lib/python3.7/dist-packages/deepul/utils.py in savefig(fname, show_figure)
#      15     plt.savefig(fname)
#      16     if show_figure:
# ---> 17         plt.show()
#      18
#      19
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     512         }
#     513
# --> 514         FigureCanvasAgg.draw(self)
#     515         if pil_kwargs is not None:
#     516             from PIL import Image
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1237         # the actual bbox
#    1238
# -> 1239         self._update_label_position(renderer)
#    1240
#    1241         self.label.draw(renderer)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2003         # if we want to align labels from other axes:
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 2005             ticks_to_draw = axx.xaxis._update_ticks()
#    2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1109             tick.set_label1(label)
#    1110             tick.set_label2(label)
# -> 1111         minor_locs = self.get_minorticklocs()
#    1112         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1113         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1351         """Get the array of minor tick locations in data coordinates."""
#    1352         # Remove minor ticks duplicating major ticks.
# -> 1353         major_locs = self.major.locator()
#    1354         minor_locs = self.minor.locator()
#    1355         transform = self._scale.get_transform()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/ticker.py in __call__(self)
#    2201     def __call__(self):
#    2202         vmin, vmax = self.axis.get_view_interval()
# -> 2203         return self.tick_values(vmin, vmax)
#    2204
#    2205     def tick_values(self, vmin, vmax):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2209         vmin, vmax = mtransforms.nonsingular(
#    2210             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2211         locs = self._raw_ticks(vmin, vmax)
#    2212
#    2213         prune = self._prune
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2149             if self.axis is not None:
#    2150                 nbins = np.clip(self.axis.get_tick_space(),
# -> 2151                                 max(1, self._min_n_ticks - 1), 9)
#    2152             else:
#    2153                 nbins = 9
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2113
#    2114     """
# -> 2115     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2116
#    2117
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      41     except AttributeError:
#      42         wrap = None
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#      44     if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     130     # This deprecation probably incurs a substantial slowdown for small arrays,
#     131     # it will be good to get rid of it.
# --> 132     if not _clip_dep_is_byte_swapped(a) and not _clip_dep_is_byte_swapped(out):
#     133         using_deprecated_nan = False
#     134         if _clip_dep_is_scalar_nan(min):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _clip_dep_is_byte_swapped(a)
#     100
#     101 def _clip_dep_is_byte_swapped(a):
# --> 102     if isinstance(a, mu.ndarray):
#     103         return not a.dtype.isnative
#     104     return False
#
# KeyboardInterrupt:

# %% [markdown]
# # Question 2: MADE
#
# In this question, you will implement [MADE](https://arxiv.org/abs/1502.03509). In the first part, you will use MADE to model a simple 2D joint distribution, and in the second half, you will train MADE on image datasets.

# %% [markdown]
# ## Part (a) Fitting 2D Data
#
# First, you will work with bivariate data of the form $x = (x_0,x_1)$, where $x_0, x_1 \in \{0, \dots, d\}$. We can easily visualize a 2D dataset by plotting a 2D histogram. Run the cell below to visualize our datasets.

# %%
visualize_q2a_data(dset_type=1)
visualize_q2a_data(dset_type=2)

# %% [markdown]
# Implement and train a MADE model through maximum likelihood to represent $p(x_0, x_1)$ on the given datasets, with any autoregressive ordering of your choosing.
#
# A few notes:
# * You do not need to do training with multiple masks
# * You made find it useful to one-hot encode your inputs.
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. Visualize the learned 2D distribution by plotting a 2D heatmap

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("GPU available, use GPU. :) ")
else:
  print("use CPU. :( ") 
class histo2(nn.Module):
  def __init__(self, d):
    super(histo2, self).__init__()
    self.d = d
    self.theta = torch.nn.parameter.Parameter(torch.zeros([self.d, self.d]))

  def forward(self, x):
    likelyhood = self.p[x[:,0],x[:,1]]
    loss = -torch.mean(torch.mean(torch.log(likelyhood)))
    return loss
    
  @property
  def p(self):
    p = torch.exp(self.theta)/torch.sum(torch.exp(self.theta))
    return p

def q2_a(train_data, test_data, d, dset_id):
  """
  train_data: An (n_train, 2) numpy array of integers in {0, ..., d-1}
  test_data: An (n_test, 2) numpy array of integers in {0, .., d-1}
  d: The number of possible discrete values for each random variable x1 and x2
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (d, d) of probabilities (the learned joint distribution)
  """
  # prepare data, model and optimizer 
  model = histo2(d).to(device)
  optimizer = optim.Adadelta(model.parameters(), lr=0.1)
  # init output
  losses = []
  test_losses = [model(torch.from_numpy(test_data).to(device)).detach().numpy().item()]

  # traning model
  model.train()
  if dset_id == 1:
    iteration = 1000
  else:
    iteration = 2000
  for iter in tqdm(range(iteration)):
    sample_idx_in_batch = np.random.choice(np.arange(train_data.shape[0]),20)
    batch = train_data[sample_idx_in_batch,:]
    model.train()
    optimizer.zero_grad()
    loss = model(torch.from_numpy(batch).to(device))
    losses.append(loss.detach().numpy().item())
    loss.backward()
    optimizer.step()
    model.eval()
    test_losses.append(model(test_data).detach().numpy().item())
  return losses, test_losses, model.p.detach().numpy()
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q2_a`, execute the cells below to visualize and save your results

# %%
q2_save_results(1, 'a', q2_a)

# %%
q2_save_results(2, 'a', q2_a)

# %% [markdown]
# ## Part (b) Shapes and MNIST
# Now, we will work with a higher dimensional datasets, namely a shape dataset and MNIST. Run the cell below to visualize the two datasets

# %%
visualize_q2b_data(1)
visualize_q2b_data(2)

# %% [markdown]
# Implement and train a MADE model on the given binary image datasets. Given some binary image of height $H$ and width $W$, we can represent image $x\in \{0, 1\}^{H\times W}$ as a flattened binary vector $x\in \{0, 1\}^{HW}$ to input into MADE to model $p_\theta(x) = \prod_{i=1}^{HW} p_\theta(x_i|x_{<i})$. Your model should output logits, after which you could apply a sigmoid over 1 logit, or a softmax over two logits (either is fine).
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from the final trained model

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
from re import X
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("GPU available, use GPU. :) ")
else:
  print("use CPU. :( ") 

class typeAB(nn.Module):
  def __init__(self, length, type='A'):
    super(typeAB, self).__init__()
    assert type in ['A', 'B']
    self.type = type
    self.length = length
    self.params = torch.nn.Parameter(torch.zeros([self.length, self.length]))
    self.bias = torch.nn.Parameter(torch.zeros([1, self.length]))
    torch.nn.init.xavier_uniform(self.params)
    torch.nn.init.xavier_uniform(self.bias)
    self.register_buffer('mask', torch.FloatTensor(self.length,self.length).uniform_() > 0.8)
  
  def forward(self, x):
    if self.type=='A':
      x = torch.mm(x, self.mask*torch.triu(self.params, diagonal=1))+self.bias
      return x
    elif self.type=='B':
      x = torch.mm(x, self.mask*torch.triu(self.params))+self.bias
      return x


class MAKE(nn.Module):
  def __init__(self, H, W, d=2, layers=4, activation=torch.nn.LeakyReLU):
    super(MAKE, self).__init__()
    assert layers>=1, "layer should be larger than 1"
    self.d = d
    self.start = torch.nn.Parameter(torch.zeros([1]).float())
    self.H = H
    self.W = W
    cond_network_architecture = nn.ModuleList([typeAB(H*W,type='A')])
    for i in range(layers-1):
      cond_network_architecture.append(activation())
      cond_network_architecture.append(typeAB(H*W,type='B'))
    cond_network_architecture.append(torch.nn.Sigmoid())
    self.cond_network = nn.Sequential(*cond_network_architecture)
    
  def forward(self, x):
    shape = x.shape
    x = x.reshape(shape[0],shape[1]*shape[2]*shape[3])
    likelyhood = self.cond_network(x.float())
    likelyhood_start = torch.sigmoid(self.start[0])*x[:,0] + (1-torch.sigmoid(self.start[0]))*(1-x[:,0])
    likelyhood_center = likelyhood[:,1:-1]*x[:,1:-1] + (1-likelyhood[:,1:-1])*(1-x[:,1:-1])
    loss = -torch.mean(torch.mean(torch.log(1e-10+torch.cat((likelyhood_start[:,None], likelyhood_center), 1))))
    return loss
  
  def generate(self,n):

    retval = []
    for i in range(n):
      retval.append(self.generate_one())
    return torch.cat(retval, dim=0)

  def generate_one(self):

    retval = torch.zeros(1,self.H*self.W)
    retval[0,0] = torch.bernoulli(torch.sigmoid(self.start[0]))
    for i in range(1, self.H*self.W):
      retval[0,i] = torch.bernoulli(self.cond_network(retval.to(device)).cpu().detach()[0,i]).item()
    return retval.reshape(1, self.H, self.W, 1)
  


def q2_b(train_data, test_data, image_shape, dset_id):
  """
  train_data: A (n_train, H, W, 1) uint8 numpy array of binary images with values in {0, 1}
  test_data: An (n_test, H, W, 1) uint8 numpy array of binary images with values in {0, 1}
  image_shape: (H, W), height and width of the image
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, W, 1) of samples with values in {0, 1}
  """
  # prepare data, model and optimizer 
  n, H, W, _ = train_data.shape
  model = MAKE(H,W,2,4).to(device)
  optimizer = optim.Adadelta(model.parameters(), lr=1)
  # init output
  losses = []
  test_losses = [model(torch.from_numpy(test_data).to(device)).cpu().detach().numpy().item()]

  # traning model
  model.train()
  if dset_id == 1:
    iteration = 100
  else:
    iteration = 100
  for iter in tqdm(range(iteration)):
    sample_idx_in_batch = np.random.choice(np.arange(train_data.shape[0]),128)
    batch = train_data[sample_idx_in_batch,:,:,:]
    optimizer.zero_grad()
    model.train()
    loss = model(torch.from_numpy(batch).to(device))
    
    loss.backward()
    optimizer.step()
    model.eval()
    if iter%10==0:
      losses.append(loss.cpu().detach().numpy().item())
      sample_idx_in_test = np.random.choice(np.arange(test_data.shape[0]),5)
      test_losses.append(model(torch.from_numpy(test_data[sample_idx_in_test,:,:,:]).to(device)).cpu().detach().numpy().item())
  return losses, test_losses, model.generate(100).cpu().detach().numpy()
  """ YOUR CODE HERE """
# Out:
# GPU available, use GPU. :)

# %% [markdown]
# ### Results
#
# Once you've implemented `q2_b`, execute the cells below to visualize and save your results

# %%
q2_save_results(1, 'b', q2_b)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c4c4f4158bb7> in <module>
# ----> 1 q2_save_results(1, 'b', q2_b)
#
# /usr/local/lib/python3.7/dist-packages/deepul/hw1_helper.py in q2_save_results(dset_type, part, fn)
#     176                              f'results/q2_{part}_dset{dset_type}_learned_dist.png')
#     177     elif part == 'b':
# --> 178         train_losses, test_losses, samples = fn(train_data, test_data, img_shape, dset_type)
#     179         samples = samples.astype('float32') * 255
#     180         print(f'Final Test Loss: {test_losses[-1]:.4f}')
#
# <ipython-input-5-a80d1ca107a2> in q2_b(train_data, test_data, image_shape, dset_id)
#      94   # init output
#      95   losses = []
# ---> 96   test_losses = [model(torch.from_numpy(test_data).to(device)).cpu().detach().numpy().item()]
#      97
#      98   # traning model
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-5-a80d1ca107a2> in forward(self, x)
#      52     shape = x.shape
#      53     x = x.reshape(shape[0],shape[1]*shape[2]*shape[3])
# ---> 54     likelyhood = self.cond_network(x.float())
#      55     likelyhood_start = torch.sigmoid(self.start[0])*x[:,0] + (1-torch.sigmoid(self.start[0]))*(1-x[:,0])
#      56     likelyhood_center = likelyhood[:,1:-1]*x[:,1:-1] + (1-likelyhood[:,1:-1])*(1-x[:,1:-1])
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-5-a80d1ca107a2> in forward(self, x)
#      27   def forward(self, x):
#      28     if self.type=='A':
# ---> 29       x = torch.mm(x, self.mask*torch.triu(self.params, diagonal=1))+self.bias
#      30       return x
#      31     elif self.type=='B':
#
# KeyboardInterrupt:

# %%
q2_save_results(2, 'b', q2_b)

# %% [markdown]
# # Question 3 PixelCNNs

# %% [markdown]
# Now, you will train more powerful PixleCNN models on the shapes dataset and MNIST. In addition, we will extend to modelling colored datasets with and without channel conditioning.

# %% [markdown]
# ## Part (a) PixelCNN on Shapes and MNIST
# In this part, implement a simple PixelCNN architecture to model binary MNIST and shapes images (same as Q2(b), but with a PixelCNN).
#
# We recommend the following network design:
# * A $7 \times 7$ masked type A convolution
# * $5$ $7 \times 7$ masked type B convolutions
# * $2$ $1 \times 1$ masked type B convolutions
# * Appropriate ReLU nonlinearities in-between
# * 64 convolutional filters
#
# And the following hyperparameters:
# * Batch size 128
# * Learning rate $10^{-3}$
# * 10 epochs
# * Adam Optimizer (this applies to all PixelCNN models trained in future parts)
#
# Your model should output logits, after which you could apply a sigmoid over 1 logit, or a softmax over two logits (either is fine). It may also help to scale your input to $[-1, 1]$ before running it through the network.
#
# Training on the shapes dataset should be quick, and MNIST should take around 10 minutes
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from the final trained model

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
from re import X
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("GPU available, use GPU. :) ")
else:
  print("use CPU. :( ") 


class MaskConv2d(nn.Conv2d):
  def __init__(self, mask_type, *arg, **kwarg):
    super(MaskConv2d, self).__init__(*arg, **kwarg)
    self.register_buffer('mask', torch.ones(self.weight.shape))
    _,_,height,width = self.weight.shape
    
    
    if mask_type == 'A':
      self.mask[:,:,height//2,width//2:] = 0
      self.mask[:,:,height//2+1:,:] = 0
    else:
      self.mask[:,:,height//2,width//2+1:] = 0
      self.mask[:,:,height//2+1:,:]=0

  def forward(self,x):
    self.weight.data*=self.mask
    return super(MaskConv2d,self).forward(x)

class PixelCNN(nn.Module):
  def __init__(self,H,W, channels=64, kernel=7, activation=torch.nn.LeakyReLU):
    super(PixelCNN, self).__init__()
    self.net = torch.nn.Sequential()
    self.net.append(MaskConv2d('A',1,channels,kernel,1,kernel//2,bias=False))
    
    self.net.append(activation(0.1))
    self.net.append(torch.nn.BatchNorm2d(channels))
    for i in range(1,4):
      self.net.append(MaskConv2d('B',channels,channels,kernel,1,kernel//2,bias=False))
      
      self.net.append(activation(0.1))
      self.net.append(torch.nn.BatchNorm2d(channels))
    self.net.append(nn.Conv2d(channels,channels,1,1,0,bias=True))
    self.net.append(activation(0.1))
    self.net.append(nn.Conv2d(channels,1,1,1,0,bias=True))
    self.net.append(torch.nn.Sigmoid())
    print(self.net)

  def forward(self,x):
    x = x.permute(0,3,1,2).float()-0.5
    p = self.net(x)
    likelyhood = p*(x+0.5) + (1-p)*(0.5-x)
    loss = -torch.mean(torch.mean(torch.mean(torch.log(likelyhood))))
    return loss

  def sample(self, n, H, W):
    retval = []
    for i in range(n):
      retval.append(self.sample_one(H,W))
    return torch.cat(retval, dim=0).permute([0,2,3,1])

  def sample_one(self, H, W):
    im = torch.zeros([100,1,H,W])
    for i in range(H):
      for j in range(W):
          im[:,0,i,j] = self.net((im-0.5).to(device))[:,0,i,j].cpu().detach()
          im[:,0,i,j] = torch.bernoulli(im[:,0,i,j])
    return im

def q3_a(train_data, test_data, image_shape, dset_id):
  """
  train_data: A (n_train, H, W, 1) uint8 numpy array of binary images with values in {0, 1}
  test_data: A (n_test, H, W, 1) uint8 numpy array of binary images with values in {0, 1}
  image_shape: (H, W), height and width of the image
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, W, 1) of samples with values in {0, 1}
  """
  n, H, W, _ = train_data.shape
  model = PixelCNN(H,W).to(device)
  optimizer = optim.Adadelta(model.parameters(), lr=0.01)
  train_loader = torch.utils.data.DataLoader(train_data, batch_size=128, shuffle=True)
  test_loader = torch.utils.data.DataLoader(test_data, batch_size=128)
  train_losses = []
  test_losses = []
  eposchs = 100

  model.eval()
  test_losses_1epoch = []
  for x in test_loader:
    test_loss = model(x.to(device)).cpu().detach().item()
    test_losses_1epoch.append(test_loss)
  test_losses.append(sum(test_losses_1epoch)/len(test_losses_1epoch))

  with tqdm(total=eposchs*(len(train_loader)+len(test_loader))) as pbar:
    for epoch in range(eposchs):
      model.train()
      for x in train_loader:
        optimizer.zero_grad()
        train_loss = model(x.to(device))
        train_loss.backward()
        optimizer.step()
        train_losses.append(train_loss.cpu().detach().item())
        pbar.update(1)
      model.eval()
      test_losses_1epoch = []
      for x in test_loader:
        test_loss = model(x.to(device)).cpu().detach().item()
        test_losses_1epoch.append(test_loss)
        pbar.update(1)
      test_losses.append(sum(test_losses_1epoch)/len(test_losses_1epoch))
  return train_losses, test_losses, model.sample(1,H,W).cpu().detach().numpy()
  """ YOUR CODE HERE """
# Out:
# GPU available, use GPU. :)

# %% [markdown]
# ### Results
#
# Once you've implemented `q3_a`, execute the cells below to visualize and save your results

# %%
q3a_save_results(1, q3_a)
# Out:
# Sequential(
#   (0): MaskConv2d(1, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (1): LeakyReLU(negative_slope=0.1)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (4): LeakyReLU(negative_slope=0.1)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (7): LeakyReLU(negative_slope=0.1)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (10): LeakyReLU(negative_slope=0.1)
#   (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (13): LeakyReLU(negative_slope=0.1)
#   (14): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (15): Sigmoid()
# )
# 100%|██████████| 11800/11800 [10:16<00:00, 19.15it/s]
# Final Test Loss: 0.0412

# %%
q3a_save_results(2, q3_a)
# Out:
# Sequential(
#   (0): MaskConv2d(1, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (1): LeakyReLU(negative_slope=0.1)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (4): LeakyReLU(negative_slope=0.1)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (7): LeakyReLU(negative_slope=0.1)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): MaskConv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (10): LeakyReLU(negative_slope=0.1)
#   (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   (13): LeakyReLU(negative_slope=0.1)
#   (14): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (15): Sigmoid()
# )
# 100%|██████████| 54800/54800 [2:02:16<00:00,  7.47it/s]
# Final Test Loss: 0.0815

# %% [markdown]
# ## Part (b) PixelCNN on Colored Shapes and MNIST: Independent Color Channels
#
# For the next two parts, we'll work with color images (shapes and MNIST). Run the cell below to visualize the dataset.

# %%
visualize_q3b_data(1)
visualize_q3b_data(2)

# %% [markdown]
# Now, implement a PixelCNN to support RGB color channels (or augment your existing implementation). **First, implement a PixelCNN that assumes color channels as independent.** More formally, we model the following parameterized distribution:
#
# $$p_\theta(x) = \prod_{i=1}^{HW}\prod_{c=1}^C p_\theta(x_i^c | x_{<i})$$
#
# Here are some tips that you may find useful for designing and training these models:
# * You will need a 4-way softmax for every prediction, as opposed to a 256-way softmax in the PixelCNN paper, since the dataset is quantized to two bits per color channel
# * You can set number of filters for each convolutions to 120. You can use the ReLU nonlinearity throughout.
# * Use a stack of 8 residual block architecture from [Figure 5](https://arxiv.org/abs/1601.06759) but with 7 x 7 masked convolutions in the middle instead of 3 x 3 masked convolutions
# * Consider using [layer normalization](https://arxiv.org/abs/1607.06450) to improve performance. However, be careful to maintain the autoregressive property.
# * With a learning rate of $10^{-3}$ and a batch size of 128, it should take a few minutes to run on the shapes dataset, and about 50-60 minutes on MNIST.
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from the final trained model

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
from torch.nn.modules.normalization import LayerNorm
from matplotlib.pyplot import xkcd
from traitlets.config.application import OrderedDict
from re import X
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm.notebook import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print("GPU available, use GPU. :) ")
else:
  print("use CPU. :( ") 

class MaskConv2d(nn.Conv2d):
  def __init__(self, mask_type, *args,color_condition=False, cond_size=None,  **kwargs):
    assert mask_type in ['A', 'B'], "Mask type should be A or B"
    super(MaskConv2d, self).__init__(*args, **kwargs)
    self.register_buffer('mask', torch.zeros(self.weight.shape))
    _,_,height,width = self.weight.shape
    
    if color_condition:
      one_third_in = self.in_channels//3
      one_third_out = self.out_channels//3
      if mask_type == 'A':
        self.mask[:,:,:height//2,:]=1
        self.mask[:,:,:height//2,:width//2]=1
        self.mask[one_third_out:2*one_third_out,:one_third_out,:height//2,:width//2]=1
        self.mask[2*one_third_out:3*one_third_out,:2*one_third_out,:height//2,:width//2]=1
      if mask_type == 'B':
        self.mask[:,:,:height//2,:]=1
        self.mask[:,:,:height//2,:width//2]=1
        self.mask[:one_third_out,:one_third_out,:height//2,:width//2]=1
        self.mask[one_third_out:2*one_third_out,:2*one_third_out,:height//2,:width//2]=1
        self.mask[2*one_third_out:3*one_third_out,:3*one_third_out,:height//2,:width//2]=1
    else:
      if mask_type == 'A':
        self.mask[:,:,:height//2,:]=1
        self.mask[:,:,height//2,:width//2]=1
      if mask_type == 'B':
        self.mask[:,:,:height//2,:]=1
        self.mask[:,:,height//2,:width//2+1]=1

  def forward(self,x):
    self.weight.data*=self.mask
    return super(MaskConv2d,self).forward(x)


class ResBlock(nn.Module):
  def __init__(self, C, *args, **kwargs):
    super(ResBlock, self).__init__(*args, **kwargs)
    self.net = torch.nn.Sequential(
      torch.nn.LeakyReLU(0.1),
      MaskConv2d('B', C, C//2, 1, 1, 0, **kwargs),
      torch.nn.LeakyReLU(0.1),
      MaskConv2d('B', C//2, C//2, 7, 1, 7//2, *args, **kwargs),
      torch.nn.LeakyReLU(0.1),
      LayerNormOverC([C//2]),
      MaskConv2d('B', C//2, C, 1, 1, 0, *args, **kwargs),
    )
  
  def forward(self, x):
    return x+self.net(x)
  
class LayerNormOverC(nn.Module):
  def __init__(self, C, color_condition=False, *args, **kwargs):
    super(LayerNormOverC, self).__init__(*args, **kwargs)
    self.C = C
    self.color_condition = color_condition
  def forward(self,x):
    if self.color_condition:
      n, C, H, W = x.shape
      x = x.view(n,C//3,3,H,W).permute([0,2,3,4,1])
      torch.nn.functional.layer_norm(x, self.C)
      x = x.permute([0,4,1,2,3]).view(x.shape)
    else:
      x = x.permute([0,2,3,1])
      torch.nn.functional.layer_norm(x, self.C)
      x = x.permute([0,3,1,2])
    return x

class PixelCNN(nn.Module):
  def __init__(self, input_shape, n_quantize, n_layers=8, channels=120, kernel=7, **kwargs):
    self.input_shape = input_shape
    C, H, W = self.input_shape
    self.n_quantize = n_quantize
    super(PixelCNN, self).__init__()
    self.net = torch.nn.Sequential()
    self.net.append(MaskConv2d('A',C,channels,kernel,1,kernel//2,**kwargs))
    self.net.append(torch.nn.BatchNorm2d(channels))
    for i in range(1,n_layers):
      self.net.append(ResBlock(channels,**kwargs))
    self.net.append(torch.nn.LeakyReLU(0.1))
    self.net.append(MaskConv2d('B', channels,C*n_quantize,1,1,0,bias=True))
    print(self.net)

  def forward(self,x):
    x = x.float()/(self.n_quantize-1)-0.5
    x = self.net(x)
    x = x.view(x.shape[0], self.n_quantize, *self.input_shape)
    return x+1e-5

  def loss(self, x):
    return torch.nn.functional.cross_entropy(self(x), x.long())

  def sample(self):
    in_channels, H, W = self.input_shape
    im = torch.zeros([100, in_channels, H, W]).cpu()
    for j in range(H):
      for k in range(W):
        for i in range(in_channels):
          prob_unscaled = F.softmax(self(im.to(device)),dim=1)[:,:,i,j,k].cpu().detach()
          im[:,i,j,k] = torch.multinomial(prob_unscaled, 1).squeeze()
    return im


def q3_b(train_data, test_data, image_shape, dset_id):
  """
  train_data: A (n_train, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  test_data: A (n_test, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  image_shape: (H, W, C), height, width, and # of channels of the image
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, W, C) of samples with values in {0, 1, 2, 3}
  """
  n, H, W, C = train_data.shape
  model = PixelCNN([C,H,W],8).to(device)
  optimizer = optim.Adam(model.parameters(), lr=0.001)
  train_loader = torch.utils.data.DataLoader(train_data, batch_size=128, shuffle=True)
  test_loader = torch.utils.data.DataLoader(test_data, batch_size=128)
  train_losses = []
  test_losses = []
  eposchs = 40

  model.eval()
  test_losses_1epoch = []
  for x in test_loader:
    test_loss = model.loss(x.to(device).permute(0,3,1,2)).cpu().detach().numpy().item()
    test_losses_1epoch.append(test_loss)
  test_losses.append(sum(test_losses_1epoch)/len(test_losses_1epoch))

  with tqdm(total=eposchs*(len(train_loader)+len(test_loader))) as pbar:
    for epoch in range(eposchs):
      model.train()
      for x in train_loader:
        optimizer.zero_grad()
        train_loss = model.loss(x.to(device).permute(0,3,1,2))
        train_loss.backward()
        optimizer.step()
        train_losses.append(train_loss.cpu().detach().numpy().item())
        pbar.update(1)
      model.eval()
      test_losses_1epoch = []
      for x in test_loader:
        test_loss = model.loss(x.to(device).permute(0,3,1,2)).cpu().detach().numpy().item()
        test_losses_1epoch.append(test_loss)
        pbar.update(1)
      test_losses.append(sum(test_losses_1epoch)/len(test_losses_1epoch))
      tqdm.write(f"Train loss {train_losses[-1]} Test loss {test_losses[-1]}")
  return train_losses, test_losses, model.sample().permute(0,2,3,1).cpu().detach().numpy()
# Out:
# GPU available, use GPU. :)

# %% [markdown]
# ### Results
#
# Once you've implemented `q3_b`, execute the cells below to visualize and save your results

# %%
q3bc_save_results(1, 'b', q3_b)
# Out:
# Sequential(
#   (0): MaskConv2d(3, 120, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (3): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (4): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (5): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (6): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (7): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (8): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (9): LeakyReLU(negative_slope=0.1)
#   (10): MaskConv2d(120, 24, kernel_size=(1, 1), stride=(1, 1))
# )
#   0%|          | 0/4720 [00:00<?, ?it/s]
# Train loss 0.2766871452331543 Test loss 0.2901234039001995
# Train loss 0.13823898136615753 Test loss 0.1347031502260102
# Train loss 0.13390831649303436 Test loss 0.11727281287312508
# Train loss 0.11192048341035843 Test loss 0.09859053811265363
# Train loss 0.10869312286376953 Test loss 0.0951203867379162
# Train loss 0.09055989235639572 Test loss 0.09415576669077079
# Train loss 0.08687176555395126 Test loss 0.09400660151408778
# Train loss 0.10775070637464523 Test loss 0.08117779530584812
# Train loss 0.07909101992845535 Test loss 0.07834069265259637
# Train loss 0.09430306404829025 Test loss 0.08477132456998031
# Train loss 0.07566890120506287 Test loss 0.0743429304824935
# Train loss 0.0739152804017067 Test loss 0.07165529268483321
# Train loss 0.07027406245470047 Test loss 0.06935852269331615
# Train loss 0.06641950458288193 Test loss 0.06540818533135785
# Train loss 0.06650218367576599 Test loss 0.06512350982262029
# Train loss 0.24580872058868408 Test loss 0.26647620192832416
# Train loss 0.07500433921813965 Test loss 0.07264929989145862
# Train loss 0.061441320925951004 Test loss 0.0653170659724209
# Train loss 0.06799735128879547 Test loss 0.06170601749585734
# Train loss 0.05799286440014839 Test loss 0.05757091225435337
# Train loss 0.047702301293611526 Test loss 0.05497832585954004
# Train loss 0.05407730117440224 Test loss 0.05307286108533541
# Train loss 0.05516636744141579 Test loss 0.05148645438667801
# Train loss 0.11874135583639145 Test loss 0.08970252320998245
# Train loss 0.05377388373017311 Test loss 0.05533392158233457
# Train loss 0.06103527173399925 Test loss 0.05019509016225735
# Train loss 0.05206288769841194 Test loss 0.05013229346109761
# Train loss 0.04714244604110718 Test loss 0.0478543055554231
# Train loss 0.04574374854564667 Test loss 0.04711312676469485
# Train loss 0.09519705921411514 Test loss 0.08312208060589102
# Train loss 0.05237819254398346 Test loss 0.04995164037164715
# Train loss 0.04645176976919174 Test loss 0.04597613091270129
# Train loss 0.04305562376976013 Test loss 0.044373353529307574
# Train loss 0.04263034462928772 Test loss 0.04422623850405216
# Train loss 0.042693767696619034 Test loss 0.044133897663818464
# Train loss 0.04127346724271774 Test loss 0.04314710717234346
# Train loss 0.03994743898510933 Test loss 0.04268551876561509
# Train loss 0.04183997958898544 Test loss 0.04226218919373221
# Train loss 0.03602338954806328 Test loss 0.04173953179270029
# Train loss 0.04039305821061134 Test loss 0.04121188105394443
# Final Test Loss: 0.0412

# %%
q3bc_save_results(2, 'b', q3_b)
# Out:
# Sequential(
#   (0): MaskConv2d(3, 120, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (3): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (4): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (5): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (6): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (7): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (8): ResBlock(
#     (net): Sequential(
#       (0): LeakyReLU(negative_slope=0.1)
#       (1): MaskConv2d(120, 60, kernel_size=(1, 1), stride=(1, 1))
#       (2): LeakyReLU(negative_slope=0.1)
#       (3): MaskConv2d(60, 60, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): LeakyReLU(negative_slope=0.1)
#       (5): LayerNormOverC()
#       (6): MaskConv2d(60, 120, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (9): LeakyReLU(negative_slope=0.1)
#   (10): MaskConv2d(120, 24, kernel_size=(1, 1), stride=(1, 1))
# )
#   0%|          | 0/21920 [00:00<?, ?it/s]
# Train loss 0.20031483471393585 Test loss 0.19940285837348504
# Train loss 0.13953213393688202 Test loss 0.13104184386850912
# Train loss 0.10816724598407745 Test loss 0.10604024546433098
# Train loss 0.09902933984994888 Test loss 0.09954909310687947
# Train loss 0.09320271760225296 Test loss 0.09394343282225766
# Train loss 0.0908360481262207 Test loss 0.09092790520266641
# Train loss 0.08865710347890854 Test loss 0.08829139786053307
# Train loss 0.11995378881692886 Test loss 0.11508824506515189
# Train loss 0.10096235573291779 Test loss 0.09992146265657642
# Train loss 0.09543202072381973 Test loss 0.09491603349960304
# Train loss 0.09200464934110641 Test loss 0.09110710864202885
# Train loss 0.09135828912258148 Test loss 0.0897981955469409
# Train loss 0.08688360452651978 Test loss 0.0880442757772494
# Train loss 0.08423972874879837 Test loss 0.08616138315653499
# Train loss 0.08575693517923355 Test loss 0.08529522892417787
# Train loss 0.08233389258384705 Test loss 0.08489888991358914
# Train loss 0.08664532005786896 Test loss 0.08357652531394476
# Train loss 0.08353837579488754 Test loss 0.08319967353268515
# Train loss 0.08326249569654465 Test loss 0.08236260287746598
# Train loss 0.08135470002889633 Test loss 0.0820321272822875
# Train loss 0.08066986501216888 Test loss 0.08167304343815092
# Train loss 0.07869426161050797 Test loss 0.08115383077271376
# Train loss 0.07883528620004654 Test loss 0.08102596362557592
# Train loss 0.08116170763969421 Test loss 0.0806305915871753
# Train loss 0.08081931620836258 Test loss 0.08010481175365328
# Train loss 0.07731737196445465 Test loss 0.07926991478174547
# Train loss 0.0774918794631958 Test loss 0.07965942179854912
# Train loss 0.07842499762773514 Test loss 0.07919194728513307
# Train loss 0.07875420898199081 Test loss 0.07919101756584795
# Train loss 0.07622812688350677 Test loss 0.07836281055513816
# Train loss 0.07690030336380005 Test loss 0.07859871866582316
# Train loss 0.07604364305734634 Test loss 0.0790665285496772
# Train loss 0.07371001690626144 Test loss 0.07854907054312621
# Train loss 0.07922033965587616 Test loss 0.07794609524403946
# Train loss 0.07565750181674957 Test loss 0.0781379890970037
# Train loss 0.073332779109478 Test loss 0.07820294467331487
# Train loss 0.07716596871614456 Test loss 0.07826044155827051
# Train loss 0.07397857308387756 Test loss 0.07790052202306216
# Train loss 0.07881347835063934 Test loss 0.07817163601329055
# Train loss 0.07618729770183563 Test loss 0.078164655951005
# Final Test Loss: 0.0782

# %% [markdown]
# ## Part (c) PixelCNN on Colored Shapes and MNIST: Autoregressive Color Channels
#
# Now, implement a PixelCNN that models **dependent** color channels. Formally, we model the parameterized distribution
#
# $$p_\theta(x) = \prod_{i=1}^{HW}\prod_{c=1}^C p_\theta(x_i^c | x_i^{<c}, x_{<i})$$
#
# To do so, change your masking scheme for the center pixel. Split the filters into 3 groups, only allowing each group to see the groups before (or including the current group, for type B masks) to maintain the autoregressive property.
#
# Training times and hyperparameter settings should be the same as part (b).
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from the final trained model

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
def q3_c(train_data, test_data, image_shape, dset_id):
  """
  train_data: A (n_train, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  test_data: A (n_test, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  image_shape: (H, W, C), height, width, and # of channels of the image
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, W, C) of samples with values in {0, 1, 2, 3}
  """
  
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q3_c`, execute the cells below to visualize and save your results

# %%
q3bc_save_results(1, 'c', q3_c)
# Out:
# Final Test Loss: 0.0236

# %%
q3bc_save_results(2, 'c', q3_c)

# %% [markdown]
# ## Part (d) Conditional PixelCNNs
#
# In this part, implement and train a **class-conditional** PixelCNN on binary MNIST. Condition on a class label by adding a conditional bias in each convolutional layer. More precisely, in the $\ell$th convolutional layer, compute:
# $$W_\ell * x + b_\ell + V_\ell y$$
# where $W_\ell * x + b_\ell$ is a masked convolution (as in previous parts), $V$ is a 2D weight matrix, and $y$ is a one-hot encoding of the class label (where the conditional bias is broadcasted spacially and added channel-wise).
#
# You can use a PixelCNN architecture similar to part (a). Training on the shapes dataset should be quick, and MNIST should take around 10-15 minutes
#
#
# **You will provide these deliverables**
#
#
# 1.   Over the course of training, record the average negative log-likelihood (nats / dim) of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from the final trained model

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
def q3_d(train_data, train_labels, test_data, test_labels, image_shape, n_classes, dset_id):
  """
  train_data: A (n_train, H, W, 1) numpy array of binary images with values in {0, 1}
  train_labels: A (n_train,) numpy array of class labels
  test_data: A (n_test, H, W, 1) numpy array of binary images with values in {0, 1}
  test_labels: A (n_test,) numpy array of class labels
  image_shape: (H, W), height and width
  n_classes: number of classes (4 or 10)
  dset_id: An identifying number of which dataset is given (1 or 2). Most likely
           used to set different hyperparameters for different datasets

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, C, 1) of samples with values in {0, 1}
    where an even number of images of each class are sampled with 100 total
  """
  
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q3_d`, execute the cells below to visualize and save your results

# %%
q3d_save_results(1, q3_d)
# Out:
# Final Test Loss: 0.0368

# %%
q3d_save_results(2, q3_d)

# %% [markdown]
# # Question 4: Bonus Questions (Optional)

# %% [markdown]
# ## Part (a) Gated PixelCNN
# Implement a [Gated PixelCNN](https://arxiv.org/abs/1606.05328) to fix the blind-spot issue, and report training curves, final test loss, and samples.

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
def q4_a(train_data, test_data, image_shape):
  """
  train_data: A (n_train, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  test_data: A (n_test, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  image_shape: (H, W, C), height, width, and # of channels of the image

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, H, W, C) of generated samples with values in {0, 1, 2, 3}
  """
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q4_a`, execute the cells below to visualize and save your results

# %%
q4a_save_results(q4_a)

# %% [markdown]
# ## Part (b) Grayscale PixelcNN
# Train a [Grayscale PixelCNN](https://arxiv.org/abs/1612.08185) on Colored MNIST. You do not need to use their architecture - stacking standard masked convolutions or residual blocks is fine. First, generate a binary image, and then the 2-bit color image.

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
def q4_b(train_data, test_data, image_shape):
  """
  train_data: A (n_train, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  test_data: A (n_test, H, W, C) uint8 numpy array of color images with values in {0, 1, 2, 3}
  image_shape: (H, W, C), height, width, and # of channels of the image

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (50, H, W, 1) of generated binary images in {0, 1}
  - a numpy array of size (50, H, W, C) of conditonally generated color images in {0, 1, 2, 3}
  """
  # You will need to generate the binary image dataset from train_data and test_data
  
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q4_b`, execute the cells below to visualize and save your results

# %%
q4b_save_results(q4_b)

# %% [markdown]
# ## Part (c) Parallel Multiscale PixelCNN
# One large disadvantage of autoregressive models is their slow sampling speed, since they require one network evaluation per feature. However, there are existing methods which introduce different independence assumptions to allow for parallelism when sampling. Implement a [Parallel PixelCNN](https://arxiv.org/abs/1703.03664) on 56 x 56 MNIST images, with a base size of 7 x 7 and upscaling by a factor of 2. Sampling should be very quick (< 1s). Architectures may vary, but using small PixelCNN implementation similar to previous parts and small ResNets should suffice

# %% [markdown]
# ### Solution
# Fill out the function below and return the necessary arguments. Feel free to create more cells if need be.

# %%
def q4_c(train_data, test_data):
  """
  train_data: A (60000, 56, 56, 1) numpy array of grayscale images with values in {0, 1}
  test_data: A (10000, 56, 56, 1) numpy array of grayscale images with values in {0, 1}
  image_shape: (H, W), height and width

  Returns
  - a (# of training iterations,) numpy array of train_losses evaluated every minibatch
  - a (# of epochs + 1,) numpy array of test_losses evaluated once at initialization and after each epoch
  - a numpy array of size (100, 56, 56, 1) of generated samples with values in {0, 1}
  """
 
  """ YOUR CODE HERE """

# %% [markdown]
# ### Results
#
# Once you've implemented `q4_c`, execute the cells below to visualize and save your results

# %%
q4c_save_results(q4_c)
